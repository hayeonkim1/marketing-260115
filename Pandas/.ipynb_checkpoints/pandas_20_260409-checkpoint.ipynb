# %%
#지금까지 내용 문법 정리

# %%
# pandas 파일 로드

import pandas as pd
doc = pd.read_csv("00_data/olist_customers_dataset.csv", encoding="utf-8-sig")
doc.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
#데이터 사이즈
doc.shape
# Out:
# (99441, 5)

# %%
#데이터 상세명세서 확인
doc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
#데이터 필드명 및 컬럼목록

doc.columns
# Out:
# Index(['customer_id', 'customer_unique_id', 'customer_zip_code_prefix',
#        'customer_city', 'customer_state'],
#       dtype='object')

# %%
#데이터 인덱스(측정기준)
doc.index
# Out:
# RangeIndex(start=0, stop=99441, step=1)

# %%
#데이터 5 numbers summary

doc.describe()
# Out:
#        customer_zip_code_prefix
# count              99441.000000
# mean               35137.474583
# std                29797.938996
# min                 1003.000000
# 25%                11347.000000
# 50%                24416.000000
# 75%                58900.000000
# max                99990.000000

# %%
#데이터 상위 5개 확인
doc.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
#raw 데이터에서 필요하다고 판단되는 컬럼만 별도로 추출해서 가져오기

doc2 = doc[["customer_zip_code_prefix","customer_city","customer_state"]].copy()
doc2
# Out:
#        customer_zip_code_prefix          customer_city customer_state
# 0                         14409                 franca             SP
# 1                          9790  sao bernardo do campo             SP
# 2                          1151              sao paulo             SP
# 3                          8775        mogi das cruzes             SP
# 4                         13056               campinas             SP
# ...                         ...                    ...            ...
# 99436                      3937              sao paulo             SP
# 99437                      6764        taboao da serra             SP
# 99438                     60115              fortaleza             CE
# 99439                     92120                 canoas             RS
# 99440                      6703                  cotia             SP
#
# [99441 rows x 3 columns]

# %%
#현재 카피해온 데이터프레임 안에서 특정 조건에 해당되는 값만 추출해오자

doc3 = doc2[doc2["customer_city"] == "sao paulo"]
doc3.shape
# Out:
# (15540, 3)

# %%
#특정 데이터프레임 내, 컬럼을 기준으로 값의 갯수 확인
doc2["customer_city"].value_counts()
# Out:
# customer_city
# sao paulo                   15540
# rio de janeiro               6882
# belo horizonte               2773
# brasilia                     2131
# curitiba                     1521
#                             ...
# olhos d'agua                    1
# pacotuba                        1
# sao sebastiao do paraiba        1
# benedito leite                  1
# campos verdes                   1
# Name: count, Length: 4119, dtype: int64

# %%
# 특정 데이터 프레인 내, 그룹화 (그룹화 대상 =인덱스)
doc4 = doc2.groupby("customer_city").count()
doc4
# Out:
#                      customer_zip_code_prefix  customer_state
# customer_city
# abadia dos dourados                         3               3
# abadiania                                   1               1
# abaete                                     12              12
# abaetetuba                                 11              11
# abaiara                                     2               2
# ...                                       ...             ...
# xinguara                                    9               9
# xique-xique                                 3               3
# zacarias                                    2               2
# ze doca                                     5               5
# zortea                                      2               2
#
# [4119 rows x 2 columns]

# %%
#특정 데이터프레임 내 인덱스의 길이 확인

len(doc4.index)
doc4.shape
# Out:
# (4119, 2)

# %%
#특정 데이터프레임 내 상위 5개문서 조회
doc4.head()
# Out:
#                      customer_zip_code_prefix  customer_state
# customer_city
# abadia dos dourados                         3               3
# abadiania                                   1               1
# abaete                                     12              12
# abaetetuba                                 11              11
# abaiara                                     2               2

# %%
doc4 = doc.groupby("customer_city").count()
doc4
# Out:
#                      customer_id  customer_unique_id  \
# customer_city
# abadia dos dourados            3                   3
# abadiania                      1                   1
# abaete                        12                  12
# abaetetuba                    11                  11
# abaiara                        2                   2
# ...                          ...                 ...
# xinguara                       9                   9
# xique-xique                    3                   3
# zacarias                       2                   2
# ze doca                        5                   5
# zortea                         2                   2
#
#                      customer_zip_code_prefix  customer_state
# customer_city
# abadia dos dourados                         3               3
# abadiania                                   1               1
# abaete                                     12              12
# abaetetuba                                 11              11
# abaiara                                     2               2
# ...                                       ...             ...
# xinguara                                    9               9
# xique-xique                                 3               3
# zacarias                                    2               2
# ze doca                                     5               5
# zortea                                      2               2
#
# [4119 rows x 4 columns]

# %%
#특정 데이터 프레임 내 컬럼을 기준으로 정렬
# doc4["cutomer_id"].sort_values(ascending =True)
doc4["customer_id"].sort_values(ascending =False).head(1)
# Out:
# customer_city
# sao paulo    15540
# Name: customer_id, dtype: int64

# %%
doc4.head()
# Out:
#                      customer_id  customer_unique_id  \
# customer_city
# abadia dos dourados            3                   3
# abadiania                      1                   1
# abaete                        12                  12
# abaetetuba                    11                  11
# abaiara                        2                   2
#
#                      customer_zip_code_prefix  customer_state
# customer_city
# abadia dos dourados                         3               3
# abadiania                                   1               1
# abaete                                     12              12
# abaetetuba                                 11              11
# abaiara                                     2               2

# %%
#데이터 프레임 내 인덱스를 새롭게 적용
doc4.set_index("customer_id")
# Out:
#              customer_unique_id  customer_zip_code_prefix  customer_state
# customer_id
# 3                             3                         3               3
# 1                             1                         1               1
# 12                           12                        12              12
# 11                           11                        11              11
# 2                             2                         2               2
# ...                         ...                       ...             ...
# 9                             9                         9               9
# 3                             3                         3               3
# 2                             2                         2               2
# 5                             5                         5               5
# 2                             2                         2               2
#
# [4119 rows x 3 columns]

# %%
doc.set_index("customer_city")
# Out:
#                                             customer_id  \
# customer_city
# franca                 06b8999e2fba1a1fbc88172c00ba8bc7
# sao bernardo do campo  18955e83d337fd6b2def6b18a428ac77
# sao paulo              4e7b3e00288586ebd08712fdd0374a03
# mogi das cruzes        b2b6027bc5c5109e529d4dc6358b12c3
# campinas               4f2d8ab171c80ec8364f7c12e35b23ad
# ...                                                 ...
# sao paulo              17ddf5dd5d51696bb3d7c6291687be6f
# taboao da serra        e7b71a9017aa05c9a7fd292d714858e8
# fortaleza              5e28dfe12db7fb50a4b2f691faecea5e
# canoas                 56b18e2166679b8a959d72dd06da27f9
# cotia                  274fa6071e5e17fe303b9748641082c8
#
#                                      customer_unique_id  \
# customer_city
# franca                 861eff4711a542e4b93843c6dd7febb0
# sao bernardo do campo  290c77bc529b7ac935b93aa66c333dc3
# sao paulo              060e732b5b29e8181a18229c7b0b2b5e
# mogi das cruzes        259dac757896d24d7702b9acbbff3f3c
# campinas               345ecd01c38d18a9036ed96c73b8d066
# ...                                                 ...
# sao paulo              1a29b476fee25c95fbafc67c5ac95cf8
# taboao da serra        d52a67c98be1cf6a5c84435bd38d095d
# fortaleza              e9f50caf99f032f0bf3c55141f019d99
# canoas                 73c2643a0a458b49f58cea58833b192e
# cotia                  84732c5050c01db9b23e19ba39899398
#
#                        customer_zip_code_prefix customer_state
# customer_city
# franca                                    14409             SP
# sao bernardo do campo                      9790             SP
# sao paulo                                  1151             SP
# mogi das cruzes                            8775             SP
# campinas                                  13056             SP
# ...                                         ...            ...
# sao paulo                                  3937             SP
# taboao da serra                            6764             SP
# fortaleza                                 60115             CE
# canoas                                    92120             RS
# cotia                                      6703             SP
#
# [99441 rows x 4 columns]

# %%
#데이터프레임 > 인덱스 내 정렬
doc.set_index("customer_city").sort_index()
# Out:
#                                           customer_id  \
# customer_city
# abadia dos dourados  a23e3f9a2b656b23b7e52075964b42cd
# abadia dos dourados  9e01f714a2b3b8962c222cf2b74c20dc
# abadia dos dourados  f11eb8f0b8b87510a93e3e1aa10b0ade
# abadiania            576d71ddb21b21763cfedce73b902180
# abaete               5e9e1ae42e02df93e9a591e86fd531a3
# ...                                               ...
# ze doca              1052e334b46dd1e9876946d6372a363e
# ze doca              d8b3ef6f73de33ae716e94d2478cc080
# ze doca              fc87e5c06780700952aa42998a22968f
# zortea               0a466d490a3c2fcc1e7177f4809ec7dd
# zortea               e046f992a304cc92e1b00d7fccdf1c42
#
#                                    customer_unique_id  \
# customer_city
# abadia dos dourados  afddf43a03a9941624ed42c0b2c17280
# abadia dos dourados  e1feae9083c4c2895ddf6dc80526a85d
# abadia dos dourados  64ee476500a01beb94df40f97a108c50
# abadiania            8d76b559181609308fcae630ea64cd61
# abaete               28af9604f7830ef6d1230fb575c39eb1
# ...                                               ...
# ze doca              c933181d09535cb6bdfb1c0160323bd9
# ze doca              9ef06526b8e57a567ed6f1dce7ab0320
# ze doca              d4798889fe74026a739ca0be9d2dccb8
# zortea               d5a5ceb83234eeb855268d7fce7f54ea
# zortea               09a3f87b74828b274d73ee9dfef43b68
#
#                      customer_zip_code_prefix customer_state
# customer_city
# abadia dos dourados                     38540             MG
# abadia dos dourados                     38540             MG
# abadia dos dourados                     38540             MG
# abadiania                               72940             GO
# abaete                                  35620             MG
# ...                                       ...            ...
# ze doca                                 65365             MA
# ze doca                                 65365             MA
# ze doca                                 65365             MA
# zortea                                  89633             SC
# zortea                                  89633             SC
#
# [99441 rows x 4 columns]

# %%
doc2
# Out:
#        customer_zip_code_prefix          customer_city customer_state
# 0                         14409                 franca             SP
# 1                          9790  sao bernardo do campo             SP
# 2                          1151              sao paulo             SP
# 3                          8775        mogi das cruzes             SP
# 4                         13056               campinas             SP
# ...                         ...                    ...            ...
# 99436                      3937              sao paulo             SP
# 99437                      6764        taboao da serra             SP
# 99438                     60115              fortaleza             CE
# 99439                     92120                 canoas             RS
# 99440                      6703                  cotia             SP
#
# [99441 rows x 3 columns]

# %%
doc2["customer_state"].value_counts().shape
# Out:
# (27,)

# %%
#특정 데이터 프레임 안에서 인덱그 요소를 해제하고 원래 컴럼자
doc4 = doc4.reset_index()
doc4
# Out:
#       index        customer_city  customer_id  customer_unique_id  \
# 0         0  abadia dos dourados            3                   3
# 1         1            abadiania            1                   1
# 2         2               abaete           12                  12
# 3         3           abaetetuba           11                  11
# 4         4              abaiara            2                   2
# ...     ...                  ...          ...                 ...
# 4114   4114             xinguara            9                   9
# 4115   4115          xique-xique            3                   3
# 4116   4116             zacarias            2                   2
# 4117   4117              ze doca            5                   5
# 4118   4118               zortea            2                   2
#
#       customer_zip_code_prefix  customer_state
# 0                            3               3
# 1                            1               1
# 2                           12              12
# 3                           11              11
# 4                            2               2
# ...                        ...             ...
# 4114                         9               9
# 4115                         3               3
# 4116                         2               2
# 4117                         5               5
# 4118                         2               2
#
# [4119 rows x 6 columns]

# %%
doc4[doc4["customer_id"] > 1000].shape
# Out:
# (9, 6)

# %%
doc4 = doc4.set_index("customer_city")
doc4
# Out:
#                      level_0  index  customer_id  customer_unique_id  \
# customer_city
# abadia dos dourados        0      0            3                   3
# abadiania                  1      1            1                   1
# abaete                     2      2           12                  12
# abaetetuba                 3      3           11                  11
# abaiara                    4      4            2                   2
# ...                      ...    ...          ...                 ...
# xinguara                4114   4114            9                   9
# xique-xique             4115   4115            3                   3
# zacarias                4116   4116            2                   2
# ze doca                 4117   4117            5                   5
# zortea                  4118   4118            2                   2
#
#                      customer_zip_code_prefix  customer_state
# customer_city
# abadia dos dourados                         3               3
# abadiania                                   1               1
# abaete                                     12              12
# abaetetuba                                 11              11
# abaiara                                     2               2
# ...                                       ...             ...
# xinguara                                    9               9
# xique-xique                                 3               3
# zacarias                                    2               2
# ze doca                                     5               5
# zortea                                      2               2
#
# [4119 rows x 6 columns]

# %%
doc4[doc4["customer_id"] > 1000].index
# Out:
# Index(['belo horizonte', 'brasilia', 'campinas', 'curitiba', 'guarulhos',
#        'porto alegre', 'rio de janeiro', 'salvador', 'sao paulo'],
#       dtype='object', name='customer_city')

# %%
doc4 = doc4.reset_index()
doc4
# Out:
#             customer_city  level_0  index  customer_id  customer_unique_id  \
# 0     abadia dos dourados        0      0            3                   3
# 1               abadiania        1      1            1                   1
# 2                  abaete        2      2           12                  12
# 3              abaetetuba        3      3           11                  11
# 4                 abaiara        4      4            2                   2
# ...                   ...      ...    ...          ...                 ...
# 4114             xinguara     4114   4114            9                   9
# 4115          xique-xique     4115   4115            3                   3
# 4116             zacarias     4116   4116            2                   2
# 4117              ze doca     4117   4117            5                   5
# 4118               zortea     4118   4118            2                   2
#
#       customer_zip_code_prefix  customer_state
# 0                            3               3
# 1                            1               1
# 2                           12              12
# 3                           11              11
# 4                            2               2
# ...                        ...             ...
# 4114                         9               9
# 4115                         3               3
# 4116                         2               2
# 4117                         5               5
# 4118                         2               2
#
# [4119 rows x 7 columns]

# %%
#데이터프레임 내 결측지 존재 여부 확인

doc.isnull().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
#수집된 데이터를 기반으로 리스트 변경하기

# doc.drop_duplicates(subset="customer_city", keep="first") #first

: 중복값 중 최초값, last : 중복값 중 최종값
doc.drop_duplicates(subset="customer_city", keep="first")["customer_city.to_list()"] #first: 중복값 중 최초값, last : 중복값 중 최종값
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'customer_city.to_list()'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[92], line 4
#       1 #수집된 데이터를 기반으로 리스트 변경하기
#       2
#       3 # doc.drop_duplicates(subset="customer_city", keep="first") #first: 중복값 중 최초값, last : 중복값 중 최종값
# ----> 4 doc.drop_duplicates(subset="customer_city", keep="first")["customer_city.to_list()"]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'customer_city.to_list()'

# %%
#피봇테이블 = > 기존데이터에서 내가 추가적으로 필터링을 해서 값을 찾아오는 것

import pandas as pd
doc_covid = pd.read_csv("COVID-19-master/csse_covid_19_data/csse_covid_19_daily_reports/04-01-2020.csv", encoding="utf-8-sig")
doc_covid.head()
# Out:
#       FIPS     Admin2  Province_State Country_Region          Last_Update  \
# 0  45001.0  Abbeville  South Carolina             US  2020-04-01 21:58:49
# 1  22001.0     Acadia       Louisiana             US  2020-04-01 21:58:49
# 2  51001.0   Accomack        Virginia             US  2020-04-01 21:58:49
# 3  16001.0        Ada           Idaho             US  2020-04-01 21:58:49
# 4  19001.0      Adair            Iowa             US  2020-04-01 21:58:49
#
#          Lat       Long_  Confirmed  Deaths  Recovered  Active  \
# 0  34.223334  -82.461707          4       0          0       4
# 1  30.295065  -92.414197         47       1          0      46
# 2  37.767072  -75.632346          7       0          0       7
# 3  43.452658 -116.241552        195       3          0     192
# 4  41.330756  -94.471059          1       0          0       1
#
#                     Combined_Key
# 0  Abbeville, South Carolina, US
# 1          Acadia, Louisiana, US
# 2         Accomack, Virginia, US
# 3                 Ada, Idaho, US
# 4                Adair, Iowa, US

# %%
import pandas as pd

doc_covid2 = pd.pivot_table(doc_covid, index=["Country_Region"], values=["Confirmed"], aggfunc={"Confirmed":"median"}, fill_value=0)
doc_covid2.head()
# Out:
#                 Confirmed
# Country_Region
# Afghanistan         192.0
# Albania             259.0
# Algeria             847.0
# Andorra             390.0
# Angola                8.0

# %%
import pandas as pd

doc_covid3 = pd.pivot_table(doc_covid,
                            index=["Country_Region"],
                            values=["Confirmed","Deaths"], 
                            aggfunc={"Confirmed":"sum","Deaths":"mean"}, 
                            fill_value=0,
                            margins=True,
                            margins_name="Total"
                           )
# doc_covid3.head()

# %%
doc_covid3
# Out:
#                       Confirmed     Deaths
# Country_Region
# Afghanistan                 192   4.000000
# Albania                     259  15.000000
# Algeria                     847  58.000000
# Andorra                     390  14.000000
# Angola                        8   2.000000
# ...                         ...        ...
# West Bank and Gaza          134   1.000000
# Winter Olympics 2022          0   0.000000
# Zambia                       36   0.000000
# Zimbabwe                      8   1.000000
# Total                    938959  20.477002
#
# [191 rows x 2 columns]

# %%
doc_covid3.style.format({
    "Confirmed": "{:,}",
    "Deaths" : "{:,.2f}"
})
# Out:
# <style type="text/css">
# </style>
# <table id="T_07bbb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_07bbb_level0_col0" class="col_heading level0 col0" >Confirmed</th>
#       <th id="T_07bbb_level0_col1" class="col_heading level0 col1" >Deaths</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Country_Region</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_07bbb_level0_row0" class="row_heading level0 row0" >Afghanistan</th>
#       <td id="T_07bbb_row0_col0" class="data row0 col0" >192</td>
#       <td id="T_07bbb_row0_col1" class="data row0 col1" >4.00</td>
#     </tr>
#     <tr>
#       <th id="T_07bbb_level0_row1" class="row_heading level0 row1" >Albania</th>
#       <td id="T_07bbb_row1_col0" class="data row1 col0" >259</td>
#       <td id="T_07bbb_row1_col1" class="data row1 col1" >15.00</td>
#     </tr>
#     <tr>
#       <th id="T_07bbb_level0_row2" class="row_heading level0 row2" >Algeria</th>
#       <td id="T_07bbb_row2_col0" class="data row2 col0" >847</td>
#       <td id="T_07bbb_row2_col1" class="data row2 col1" >58.00</td>
#     </tr>
#     <tr>
#       <th id="T_07bbb_level0_row3" class="row_heading level0 row3" >Andorra</th>
#       <td id="T_07bbb_row3_col0" class="data row3 col0" >390</td>
#       <td id="T_07bbb_row3_col1" class="data row3 col1" >14.00</td>
#     </tr>
#     <tr>
#       <th id="T_07bbb_level0_row4" class="row_heading level0 row4" >Angola</th>
#       <td id="T_07bbb_row4_col0" class="data row4 col0" >8</td>
#       <td id="T_07bbb_row4_col1" class="data row4 col1" >2.00</td>
#     </tr>
#     <tr>
#       <th id="T_07bbb_level0_row5" class="row_heading level0 row5" >Antarctica</th>
#       <td id="T_07bbb_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_07bbb_row5_col1" class="data row5 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_07bbb_level0_row6" class="row_heading level0 row6" >Antigua and Barbuda</th>
#       <td id="T_07bbb_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_07bbb_row6_col1" class="data row6 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_07bbb_level0_row7" class="row_heading level0 row7" >Argentina</th>
#       <td id="T_07bbb_row7_col0" class="data row7 col0" >1,054</td>
#       <td id="T_07bbb_row7_col1" class="data row7 col1" >28.00</td>
#     </tr>
#     <tr>
#       <th id="T_07bbb_level0_row8" class="row_heading level0 row8" >Armenia</th>
#       <td id="T_07bbb_row8_col0" class="data row8 col0" >571</td>
#       <td id="T_07bbb_row8_col1" class="data row8 col1" >4.00</td>
#     </tr>
#     <tr>
#       <th id="T_07bbb_level0_row9" class="row_heading level0 row9" >Australia</th>
#       <td id="T_07bbb_row9_col0" class="data row9 col0" >4,862</td>
#       <td id="T_07bbb_row9_col1" class="data row9 col1" >2.50</td>
#     </tr>
#     <tr>
#       <th id="T_07bbb_level0_row10" class="row_heading level0 row10" >Austria</th>
#       <td id="T_07bbb_row10_col0" class="data row10 col0" >9,937</td>
#       <td id="T_07bbb_row10_col1" class="data row10 col1" >155.00</td>
#     </tr>
#     <tr>
#       <th id="T_07bbb_level0_row11" class="row_heading level0 row11" >Azerbaijan</th>
#       <td id="T_07bbb_row11_col0" class="data row11 col0" >359</td>
#       <td id="T_07bbb_row11_col1" class="data row11 col1" >5.00</td>
#     </tr>
#     <tr>
#       <th id="T_07bbb_level0_row12" class="row_heading level0 row12" >Bahamas</th>
#       <td id="T_07bbb_row12_col0" class="data row12 col0" >21</td>
#       <td id="T_07bbb_row12_col1" class="data row12 col1" >1.00</td>
#     </tr>
#     <tr>
#       <th id="T_07bbb_level0_row13" class="row_heading level0 row13" >Bahrain</th>
#       <td id="T_07bbb_row13_col0" class="data row13 col0" >569</td>
#       <td id="T_07bbb_row13_col1" class="data row13 col1" >4.00</td>
#     </tr>
#     <tr>
#       <th id="T_07bbb_level0_row14" class="row_heading level0 row14" >Bangladesh</th>
#       <td id="T_07bbb_row14_col0" class="data row14 col0" >54</td>
#       <td id="T_07bbb_row14_col1" class="data row14 col1" >6.00</td>
#     </tr>
#     <tr>
#       <th id="T_07bbb_level0_row15" class="row_heading level0 row15" >Barbados</th>
#       <td id="T_07bbb_row15_col0" class="data row15 col0" >34</td>
#       <td id="T_07bbb_row15_col1" class="data row15 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_07bbb_level0_row16" class="row_heading level0 row16" >Belarus</th>
#       <td id="T_07bbb_row16_col0" class="data row16 col0" >163</td>
#       <td id="T_07bbb_row16_col1" class="data row16 col1" >2.00</td>
#     </tr>
#     <tr>
#       <th id="T_07bbb_level0_row17" class="row_heading level0 row17" >Belgium</th>
#       <td id="T_07bbb_row17_col0" class="data row17 col0" >13,964</td>
#       <td id="T_07bbb_row17_col1" class="data row17 col1" >828.00</td>
#     </tr>
#     <tr>
#       <th id="T_07bbb_level0_row18" class="row_heading level0 row18" >Belize</th>
#       <td id="T_07bbb_row18_col0" class="data row18 col0" >3</td>
#       <td id="T_07bbb_row18_col1" class="data row18 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_07bbb_level0_row19" class="row_heading level0 row19" >Benin</th>
#       <td id="T_07bbb_row19_col0" class="data row19 col0" >13</td>
#       <td id="T_07bbb_row19_col1" class="data row19 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_07bbb_level0_row20" class="row_heading level0 row20" >Bhutan</th>
#       <td id="T_07bbb_row20_col0" class="data row20 col0" >4</td>
#       <td id="T_07bbb_row20_col1" class="data row20 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_07bbb_level0_row21" class="row_heading level0 row21" >Bolivia</th>
#       <td id="T_07bbb_row21_col0" class="data row21 col0" >115</td>
#       <td id="T_07bbb_row21_col1" class="data row21 col1" >7.00</td>
#     </tr>
#     <tr>
#       <th id="T_07bbb_level0_row22" class="row_heading level0 row22" >Bosnia and Herzegovina</th>
#       <td id="T_07bbb_row22_col0" class="data row22 col0" >459</td>
#       <td id="T_07bbb_row22_col1" class="data row22 col1" >13.00</td>
#     </tr>
#     <tr>
#       <th id="T_07bbb_level0_row23" class="row_heading level0 row23" >Botswana</th>
#       <td id="T_07bbb_row23_col0" class="data row23 col0" >4</td>
#       <td id="T_07bbb_row23_col1" class="data row23 col1" >1.00</td>
#     </tr>
#     <tr>
#       <th id="T_07bbb_level0_row24" class="row_heading level0 row24" >Brazil</th>
#       <td id="T_07bbb_row24_col0" class="data row24 col0" >6,836</td>
#       <td id="T_07bbb_row24_col1" class="data row24 col1" >240.00</td>
#     </tr>
#     <tr>
#       <th id="T_07bbb_level0_row25" class="row_heading level0 row25" >Brunei</th>
#       <td id="T_07bbb_row25_col0" class="data row25 col0" >131</td>
#       <td id="T_07bbb_row25_col1" class="data row25 col1" >1.00</td>
#     </tr>
#     <tr>
#       <th id="T_07bbb_level0_row26" class="row_heading level0 row26" >Bulgaria</th>
#       <td id="T_07bbb_row26_col0" class="data row26 col0" >422</td>
#       <td id="T_07bbb_row26_col1" class="data row26 col1" >10.00</td>
#     </tr>
#     <tr>
#       <th id="T_07bbb_level0_row27" class="row_heading level0 row27" >Burkina Faso</th>
#       <td id="T_07bbb_row27_col0" class="data row27 col0" >282</td>
#       <td id="T_07bbb_row27_col1" class="data row27 col1" >16.00</td>
#     </tr>
#     <tr>
#       <th id="T_07bbb_level0_row28" class="row_heading level0 row28" >Burma</th>
#       <td id="T_07bbb_row28_col0" class="data row28 col0" >15</td>
#       <td id="T_07bbb_row28_col1" class="data row28 col1" >1.00</td>
#     </tr>
#     <tr>
#       <th id="T_07bbb_level0_row29" class="row_heading level0 row29" >Burundi</th>
#       <td id="T_07bbb_row29_col0" class="data row29 col0" >2</td>
#       <td id="T_07bbb_row29_col1" class="data row29 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_07bbb_level0_row30" class="row_heading level0 row30" >Cabo Verde</th>
#       <td id="T_07bbb_row30_col0" class="data row30 col0" >6</td>
#       <td id="T_07bbb_row30_col1" class="data row30 col1" >1.00</td>
#     </tr>
#     <tr>
#       <th id="T_07bbb_level0_row31" class="row_heading level0 row31" >Cambodia</th>
#       <td id="T_07bbb_row31_col0" clas

# %%
doc_covid3[doc_covid3.index == "Total"]
# Out:
#                 Confirmed     Deaths
# Country_Region
# Total              938959  20.477002
