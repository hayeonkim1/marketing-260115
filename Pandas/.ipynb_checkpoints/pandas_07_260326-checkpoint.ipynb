# %%
# Pandas :1) 1차원 데이터 Series // 2) 2차원데이터 Dataframe

#행/열이 생기기 시작함.
#시리즈가 여러개 생김
#[]가 여러개 있어야함

#다수의 시리즈 식별
#각 시리즈의 식별값 : Field 
#field명들의 모임: Columns
#그 안의 값들: Values

# %%
import pandas as pd

df = pd.DataFrame({
    [],
    [], []
})  #딕셔너리형태를 띄지만 딕셔너리는 아님
