# %%
#데이터 구조 :  파일 포맷 - plain text, csv, xml, json

# %%
import json 

data = '{"id":"01", "language": "Java", "eddition" : "third", "author":"David Park"}'

jsondata = json.loads(data)
print(jsondata, jsondata["id"], jsondata["language"])
# Out:
# {'id': '01', 'language': 'Java', 'eddition': 'third', 'author': 'David Park'} 01 Java

# %%
import json 

data = {"id":"01", "language": "Java", "eddition" : "third", "author": "David Park"}
jsondata = json.dumps(data)
print(jsondata)
# Out:
# {"id": "01", "language": "Java", "eddition": "third", "author": "David Park"}

# %%
import json 

data = {"id":"01", "language": "Python", "eddition" : "third", "author": "David Park"}

with open("00_data/test01.json", "w", encoding= "utf-8-sig") as json_file :
    json_string = json.dump(data, json_file, indent=2)

# %%
import json

with open("00_data/US_category_id.json","r", encoding="utf-8-sig") as json_file :
    json_data = json.load(json_file)
    for item in json_data['items'] :
        print(item['kind'])
# Out:
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
