# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
import time

URL = "https://www.melon.com/index.htm"

service = Service(ChromeDriverManager().install())
options= Options()

# options.add_argument("--headless")
# options.add_argument("--disable-gpu")
options.add_argument("--disable-dev-shm-usage")
options.add_argument("--window-size=1920,1080")
options.add_argument("--start-maximized")
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36")
options.add_argument("--lang=ko_KR")
options.add_argument("--no-snadbox")

driver= webdriver.Chrome(service=service, options=options)
driver.get(URL)
time.sleep(3)

search_button = driver.find_element(By.CSS_SELECTOR, "input.ui-autocomplete-input")
search_button.click()
search_button.clear()
search_button.send_keys("소녀시대")
search_button.send_keys(Keys.RETURN)
time.sleep(2)

group_info = driver.find_element(By.CSS_SELECTOR, "div.atist_dtl_info").text

artist_button = driver.find_element(By.CSS_SELECTOR,"div.atist_info a.ellipsis")
artist_button.click()
time.sleep(2)

artist_info = driver.find_element(By.CSS_SELECTOR,"div.wrap_atist_info").text

print(f"GROUP: {group_info}, ARTIST: {artist_info}")
# Out:
# GROUP: 소녀시대 (GIRLS' GENERATION)
# 팬맺기
# 75,435
# 국적
# 대한민국
# 활동유형
# 여성, 그룹
# 활동년대
# 2000,2010,2020
# 활동장르
# 댄스, 발라드, 일렉트로니카
# 데뷔(곡)
# 2007.08.05
# 곡재생 다시 만난 세계 (Into The New World)
# 결성일
# 2007
# 멤버
# 태연 (TAEYEON) , 써니 (SUNNY) , 유리 (YURI) , 수영 (SOOYOUNG) , Tiffany Young , 서현 (SEOHYUN) , 윤아 (YOONA) , 효연 (HYOYEON), /n ARTIST: 태연 (TAEYEON)
# 데뷔
# 2015.10.07 곡재생 I (Feat. 버벌진트)
# 생일
# 1989.03.09
# 활동유형
# 솔로
# 소속사
# (주)SM엔터테인먼트
# 수상이력
# 제39회 골든디스크 어워즈|디지털 음원 본상
# 더보기
# 공유하기
# 친구
# 페이스북
# 트위터

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
from pymongo import MongoClient
import time

client = MongoClient("mongodb://localhost:27017") #서버계정 정보
db = client["melon"]   #db명 만들기
collection = db["girlsgeneration"]  #db의 collection만들기

documents= []

URL = "https://www.melon.com/index.htm"

service = Service(ChromeDriverManager().install())
options= Options()

# options.add_argument("--headless")
# options.add_argument("--disable-gpu")
options.add_argument("--disable-dev-shm-usage")
options.add_argument("--window-size=1920,1080")
options.add_argument("--start-maximized")
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36")
options.add_argument("--lang=ko_KR")
options.add_argument("--no-snadbox")

driver= webdriver.Chrome(service=service, options=options)
driver.get(URL)
time.sleep(3)

search_button = driver.find_element(By.CSS_SELECTOR, "input.ui-autocomplete-input")
search_button.click()
search_button.clear()
search_button.send_keys("소녀시대")
search_button.send_keys(Keys.RETURN)
time.sleep(2)

tag = dl.find_elements(By.TAG_NAME, "dt")
information = dl.find_elements(By.TAG_NAME, "dd")

group_info = []

for i in range(len(dts)):
    group_info.append(tag[i].text + ": " + information[i].text)

artist_button = driver.find_element(By.CSS_SELECTOR,"div.atist_info a.ellipsis")
artist_button.click()
time.sleep(2)

artist_info = driver.find_element(By.CSS_SELECTOR,"div.wrap_atist_info").text




doc= {
    "group": group_info , "artist": artist_info
}
documents.append(doc)

if documents :
        collection.insert_many(documents)
client.close()
print("전송완료")
# Out:
# 전송완료

# %%
dl = driver.find_element(By.CSS_SELECTOR, "dl.info_02.clfix")

dts = dl.find_elements(By.TAG_NAME, "dt")
dds = dl.find_elements(By.TAG_NAME, "dd")

result = []

for i in range(len(dts)):
    result.append(dts[i].text + ": " + dds[i].text)

print(result)
