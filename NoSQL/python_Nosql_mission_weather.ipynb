# %%
import requests
from bs4 import BeautifulSoup

res = requests.get("https://www.weather.go.kr/w/index.do")
soup = BeautifulSoup(res.content, "html.parser")

category = soup.get('li > a[href="/w/special-report/overall.do"]')
overall = soup.get('div.section-wrap > li a[href="/w/forecast/overall/short-term.do"]')

for tab_num in range (10):
    if tab_num == 1 :
         local = requests.get("ul.flex.flex-wrap.items-center.gap-2 > li > a[data-tab]")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\urllib3\util\url.py:423, in parse_url(url)
#     422 auth = auth or None
# --> 423 host, port = _HOST_PORT_RE.match(host_port).groups()  # type: ignore[union-attr]
#     424 if auth and normalize_uri:
#
# AttributeError: 'NoneType' object has no attribute 'groups'
#
# The above exception was the direct cause of the following exception:
#
# LocationParseError                        Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\requests\models.py:433, in PreparedRequest.prepare_url(self, url, params)
#     432 try:
# --> 433     scheme, auth, host, port, path, query, fragment = parse_url(url)
#     434 except LocationParseError as e:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\urllib3\util\url.py:449, in parse_url(url)
# ...
