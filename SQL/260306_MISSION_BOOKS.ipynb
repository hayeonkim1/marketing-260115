# %%
import requests
from bs4 import BeautifulSoup

for page_num in range(8) :
    if page_num == 0 :
        res = requests.get("https://davelee-fun.github.io/")
    else :
        res = requests.get(f"https://davelee-fun.github.io/page{str(page_num +1)}")
    soup = BeautifulSoup(res.content, "html.parser")

    for item in data :
        category = item.select_one("h2.card-title").get_text().replace("관련 상품 추천", "").strip()
        product = item.select_one("h4.card-text").get_text().replace("상품명: ","").strip()
        print(category, product)

# %% [markdown]
# #크롤링 할 값 ㄲ
# CATEGORY NAME
# TITLE
# PRICE
# STOCK

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get("https://books.toscrape.com/")
soup = BeautifulSoup(res.content, "html.parser")

categories = soup.select("div.side_categories ul li ul li a")

# for element in range(20):
    # .get_text().strip()
print(categories.get_text().strip())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 11
#       7 categories = soup.select("div.side_categories ul li ul li a")
#       9 # for element in range(20):
#      10     # .get_text().strip()
# ---> 11 print(categories.get_text().strip())
#
# File C:\ProgramData\anaconda3\Lib\site-packages\bs4\element.py:2433, in ResultSet.__getattr__(self, key)
#    2431 def __getattr__(self, key):
#    2432     """Raise a helpful exception to explain a common code fix."""
# -> 2433     raise AttributeError(
#    2434         "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2435     )
#
# AttributeError: ResultSet object has no attribute 'get_text'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?
