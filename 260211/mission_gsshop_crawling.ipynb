# %% [markdown]
# [오늘의 미션] 2/11
# selenium을 활용한 crawling 미션
# https://www.gsshop.com/ 방문 후 TV편성표 방문
# 홈쇼핑 방송 시간 + 방송상품명 을 크롤링하기

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC #-> 알림창 같은 unexpected condition 방지를 위해
from selenium.webdriver.support.ui import WebDriverWait
from webdriver_manager.chrome import ChromeDriverManager
import time


URL = "https://www.gsshop.com/"

service = Service(ChromeDriverManager().install())
options= Options()

# options.add_argument("--headless")
# options.add_argument("--disable-gpu")
options.add_argument("--disable-dev-shm-usage")
options.add_argument("--window-size=1920,1080")
options.add_argument("--start-maximized")
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36")
options.add_argument("--lang=ko_KR")
options.add_argument("--no-snadbox")

driver= webdriver.Chrome(service=service, options=options)
driver.get(URL)
time.sleep(3)

tvtab = driver.find_element(By.CSS_SELECTOR, "a#tvScheduleMain")
tvtab.click()
time.sleep(3)

wait = WebDriverWait(driver, 10)

driver.execute_script(f"window.scrollTo(0, 0);")
time.sleep(1)

schedules = driver.find_elements(By.CSS_SELECTOR,"section#onair-Schedule")
program_data = list()

for schedule in schedules :
    
    items = schedule.find_elements(By.CSS_SELECTOR, "article.items")

    for item in items :
        time = item.find_elements(By.CSS_SELECTOR,"aside span.times").text.strip()
        product = item.find_elements(By.CSS_SELECTOR, "ul > li > dl > dt.prd-name").text.strip()
    program_data.append({
        "방송시간: ", time, "방송상품: ", product 
    })
    print(program_data)


driver.quit()
