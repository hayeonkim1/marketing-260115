# %% [markdown]
# [오늘의 미션] 2/11
# selenium을 활용한 crawling 미션
# https://www.gsshop.com/ 방문 후 TV편성표 방문
# 홈쇼핑 방송 시간 + 방송상품명 을 크롤링하기

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC #-> 알림창 같은 unexpected condition 방지를 위해
from selenium.webdriver.support.ui import WebDriverWait
from webdriver_manager.chrome import ChromeDriverManager
import time


URL = "https://www.gsshop.com/"

service = Service(ChromeDriverManager().install())
options= Options()

# options.add_argument("--headless")
# options.add_argument("--disable-gpu")
options.add_argument("--disable-dev-shm-usage")
options.add_argument("--window-size=1920,1080")
options.add_argument("--start-maximized")
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36")
options.add_argument("--lang=ko_KR")
options.add_argument("--no-snadbox")

driver= webdriver.Chrome(service=service, options=options)
driver.get(URL)
time.sleep(3)

button = driver.find_element(By.CSS_SELECTOR, "a#tvScheduleMain")
button.click()
time.sleep(3)

driver.execute_script("window.scrollTo(0,0)")
time.sleep(2)

items = driver.find_elements(By.CSS_SELECTOR, "article.items")

for item in items : 
    time = driver.find_element(By.CSS_SELECTOR, "span.times").text.strip()
    product = driver.find_element(By.CSS_SELECTOR, "ul > li > dl > dt.prd-name").text.strip()
    print(f"방송시간: {time}, 상품명: {product}")

driver.quit()
# Out:
# 방송시간: 01:05, 상품명: [TV상품] 뉴온 시서스 필 다이어트 6박스
# 방송시간: 01:05, 상품명: [TV상품] 뉴온 시서스 필 다이어트 6박스
# 방송시간: 01:05, 상품명: [TV상품] 뉴온 시서스 필 다이어트 6박스
# 방송시간: 01:05, 상품명: [TV상품] 뉴온 시서스 필 다이어트 6박스
# 방송시간: 01:05, 상품명: [TV상품] 뉴온 시서스 필 다이어트 6박스
# 방송시간: 01:05, 상품명: [TV상품] 뉴온 시서스 필 다이어트 6박스
# 방송시간: 01:05, 상품명: [TV상품] 뉴온 시서스 필 다이어트 6박스
# 방송시간: 01:05, 상품명: [TV상품] 뉴온 시서스 필 다이어트 6박스
# 방송시간: 01:05, 상품명: [TV상품] 뉴온 시서스 필 다이어트 6박스
# 방송시간: 01:05, 상품명: [TV상품] 뉴온 시서스 필 다이어트 6박스
# 방송시간: 01:05, 상품명: [TV상품] 뉴온 시서스 필 다이어트 6박스
# 방송시간: 01:05, 상품명: [TV상품] 뉴온 시서스 필 다이어트 6박스
# 방송시간: 01:05, 상품명: [TV상품] 뉴온 시서스 필 다이어트 6박스
# 방송시간: 01:05, 상품명: [TV상품] 뉴온 시서스 필 다이어트 6박스
# 방송시간: 01:05, 상품명: [TV상품] 뉴온 시서스 필 다이어트 6박스
# 방송시간: 01:05, 상품명: [TV상품] 뉴온 시서스 필 다이어트 6박스
# 방송시간: 01:05, 상품명: [TV상품] 뉴온 시서스 필 다이어트 6박스
# 방송시간: 01:05, 상품명: [TV상품] 뉴온 시서스 필 다이어트 6박스
# 방송시간: 01:05, 상품명: [TV상품] 뉴온 시서스 필 다이어트 6박스
# 방송시간: 01:05, 상품명: [TV상품] 뉴온 시서스 필 다이어트 6박스

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC #-> 알림창 같은 unexpected condition 방지를 위해
from selenium.webdriver.support.ui import WebDriverWait
from webdriver_manager.chrome import ChromeDriverManager
import time


URL = "https://www.gsshop.com/"

service = Service(ChromeDriverManager().install())
options= Options()

# options.add_argument("--headless")
# options.add_argument("--disable-gpu")
options.add_argument("--disable-dev-shm-usage")
options.add_argument("--window-size=1920,1080")
options.add_argument("--start-maximized")
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36")
options.add_argument("--lang=ko_KR")
options.add_argument("--no-snadbox")

driver= webdriver.Chrome(service=service, options=options)
driver.get(URL)
time.sleep(3)

tvtab = driver.find_element(By.CSS_SELECTOR, "a#tvScheduleMain")
tvtab.click()
time.sleep(3)


driver.execute_script(f"window.scrollTo(0, 0);")
time.sleep(2)

# schedules = driver.find_elements(By.CSS_SELECTOR,"section#onair-Schedule")
# program_data = list()


    
items = driver.find_elements(By.CSS_SELECTOR, "article.items")

for item in items :
    time = item.find_element(By.CSS_SELECTOR,"aside span.times").text.strip()
    product = item.find_element(By.CSS_SELECTOR, "ul > li > dl > dt.prd-name").text.strip()
    print(f"방송시간: {time} 방송상품: {product}")





driver.quit()
# Out:
# 방송시간: 01:05 방송상품: [TV상품] 뉴온 시서스 필 다이어트 6박스
# 방송시간: 02:00 방송상품: [TV상품] [나에게맞는맞춤설계] FM에셋 무료보험상담
# 방송시간: 03:00 방송상품: [TV상품] 25년 최신상 쉘퍼 대용량 워셔블 음식물처리기 맥스 5.5L DFFP-MAX100
# 방송시간: 03:30 방송상품: [TV상품] [나에게맞는맞춤설계] FM에셋 무료보험상담
# 방송시간: 04:30 방송상품: [TV상품] [나에게맞는맞춤설계] FM에셋 무료보험상담
# 방송시간: 05:30 방송상품: [TV상품] 문은희 속초 명태회무침 400g 4통 총1.6kg
# 방송시간: 06:00 방송상품: [TV상품] 프리미엄 오한진의 백세알부민 2+2+2박스(180병)구성
# 방송시간: 07:15 방송상품: [TV상품] 셀폰즈 녹는실 리프팅 앰플 매니아 패키지
# 방송시간: 08:15 방송상품: [TV상품] [주영엔에스 단백질 저분자 유청펩타이드 HW-3] 12주(84포)
# 방송시간: 09:20 방송상품: [TV상품] 시슬리 26SS 시그니처 비딩 브라이트 윈드재킷
# 방송시간: 11:50 방송상품: [TV상품] 셀리맥스 트라넥삼산 최고함량 크림 단품
# 방송시간: 12:50 방송상품: [TV상품] [상담만 받아도 특별한혜택] (무)원스톱프리미엄암보험_진단금플랜
# 방송시간: 13:50 방송상품: [TV상품] [퓨레어] 퍼퓸 탈취제 싱글구성 10개 (라벤더4+화이트머스크4+무향2)
# 방송시간: 15:05 방송상품: [TV상품] 맥스클리닉 더플트러플 오일폼 단품
# 방송시간: 16:10 방송상품: [TV상품] 웰라쥬 캡슐 앰플 시즌4 기본구성
# 방송시간: 17:25 방송상품: [TV상품] 이지듀 한가인 기미앰플 사상최대용량 특대 30ml*4통+ 점보 15ml*1통+글루타치온 크림 특대 105ml(리뷰시)
# 방송시간: 18:35 방송상품: [TV상품] [롯데관광] 나고야 여행 상담예약 (3박 4일)
# ...
