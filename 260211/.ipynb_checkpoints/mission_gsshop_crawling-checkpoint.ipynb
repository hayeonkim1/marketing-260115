# %% [markdown]
# [오늘의 미션] 2/11
# selenium을 활용한 crawling 미션
# https://www.gsshop.com/ 방문 후 TV편성표 방문
# 홈쇼핑 방송 시간 + 방송상품명 을 크롤링하기

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC #-> 알림창 같은 unexpected condition 방지를 위해
from selenium.webdriver.support.ui import WebDriverWait
from webdriver_manager.chrome import ChromeDriverManager
import time


URL = "https://www.gsshop.com/"

service = Service(ChromeDriverManager().install())
options= Options()

# options.add_argument("--headless")
# options.add_argument("--disable-gpu")
options.add_argument("--disable-dev-shm-usage")
options.add_argument("--window-size=1920,1080")
options.add_argument("--start-maximized")
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36")
options.add_argument("--lang=ko_KR")
options.add_argument("--no-snadbox")

driver= webdriver.Chrome(service=service, options=options)
driver.get(URL)
time.sleep(3)

button = driver.find_element(By.CSS_SELECTOR, "a#tvScheduleMain")
button.click()
time.sleep(3)

driver.execute_script("window.scrollTo(0,0)")
time.sleep(2)

items = driver.find_elements(By.CSS_SELECTOR, "article.items")

for item in items : 
    time = driver.find_element(By.CSS_SELECTOR, "span.times").text.strip()
    product = driver.find_element(By.CSS_SELECTOR, "ul > li > dl > dt.prd-name").text.strip()
    print(f"방송시간: {time}, 상품명: {product}")

driver.quit()
# Out:
# 방송시간: 01:00, 상품명: [TV상품] 뉴온 시서스 필 다이어트 6박스
# 방송시간: 01:00, 상품명: [TV상품] 뉴온 시서스 필 다이어트 6박스
# 방송시간: 01:00, 상품명: [TV상품] 뉴온 시서스 필 다이어트 6박스
# 방송시간: 01:00, 상품명: [TV상품] 뉴온 시서스 필 다이어트 6박스
# 방송시간: 01:00, 상품명: [TV상품] 뉴온 시서스 필 다이어트 6박스
# 방송시간: 01:00, 상품명: [TV상품] 뉴온 시서스 필 다이어트 6박스
# 방송시간: 01:00, 상품명: [TV상품] 뉴온 시서스 필 다이어트 6박스
# 방송시간: 01:00, 상품명: [TV상품] 뉴온 시서스 필 다이어트 6박스
# 방송시간: 01:00, 상품명: [TV상품] 뉴온 시서스 필 다이어트 6박스
# 방송시간: 01:00, 상품명: [TV상품] 뉴온 시서스 필 다이어트 6박스
# 방송시간: 01:00, 상품명: [TV상품] 뉴온 시서스 필 다이어트 6박스
# 방송시간: 01:00, 상품명: [TV상품] 뉴온 시서스 필 다이어트 6박스
# 방송시간: 01:00, 상품명: [TV상품] 뉴온 시서스 필 다이어트 6박스
# 방송시간: 01:00, 상품명: [TV상품] 뉴온 시서스 필 다이어트 6박스
# 방송시간: 01:00, 상품명: [TV상품] 뉴온 시서스 필 다이어트 6박스
# 방송시간: 01:00, 상품명: [TV상품] 뉴온 시서스 필 다이어트 6박스
# 방송시간: 01:00, 상품명: [TV상품] 뉴온 시서스 필 다이어트 6박스
# 방송시간: 01:00, 상품명: [TV상품] 뉴온 시서스 필 다이어트 6박스
# 방송시간: 01:00, 상품명: [TV상품] 뉴온 시서스 필 다이어트 6박스
# 방송시간: 01:00, 상품명: [TV상품] 뉴온 시서스 필 다이어트 6박스
# 방송시간: 01:00, 상품명: [TV상품] 뉴온 시서스 필 다이어트 6박스
# 방송시간: 01:00, 상품명: [TV상품] 뉴온 시서스 필 다이어트 6박스
# 방송시간: 01:00, 상품명: [TV상품] 뉴온 시서스 필 다이어트 6박스
# 방송시간: 01:00, 상품명: [TV상품] 뉴온 시서스 필 다이어트 6박스

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC #-> 알림창 같은 unexpected condition 방지를 위해
from selenium.webdriver.support.ui import WebDriverWait
from webdriver_manager.chrome import ChromeDriverManager
import time


URL = "https://www.gsshop.com/"

service = Service(ChromeDriverManager().install())
options= Options()

# options.add_argument("--headless")
# options.add_argument("--disable-gpu")
options.add_argument("--disable-dev-shm-usage")
options.add_argument("--window-size=1920,1080")
options.add_argument("--start-maximized")
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36")
options.add_argument("--lang=ko_KR")
options.add_argument("--no-snadbox")

driver= webdriver.Chrome(service=service, options=options)
driver.get(URL)
time.sleep(3)

tvtab = driver.find_element(By.CSS_SELECTOR, "a#tvScheduleMain")
tvtab.click()
time.sleep(3)


driver.execute_script(f"window.scrollTo(0, 0);")
time.sleep(2)

# schedules = driver.find_elements(By.CSS_SELECTOR,"section#onair-Schedule")
# program_data = list()


    
items = driver.find_elements(By.CSS_SELECTOR, "article.items")

for item in items :
    time = item.find_element(By.CSS_SELECTOR,"aside span.times").text.strip()
    product = item.find_element(By.CSS_SELECTOR, "ul > li > dl > dt.prd-name").text.strip()
    print(f"방송시간: {time} 방송상품: {product}")





driver.quit()
# Out:
# 방송시간: 01:00 방송상품: [TV상품] 뉴온 시서스 필 다이어트 6박스
# 방송시간: 02:00 방송상품: [TV상품] 스퀘어가든 폴딩 양면그릴 원터치 전기그릴 GS단독구성 풀세트
# 방송시간: 03:10 방송상품: [TV상품] 그레인온 캡슐레이션효소 12박스
# 방송시간: 03:40 방송상품: [TV상품] [25년 햇김] 해농 세번구운 지주식곱창돌김 200매
# 방송시간: 04:10 방송상품: [TV상품] 코렐 일렉 에어글라스 에어프라이어 스페셜패키지 (1.5L 글라스 2개 더)
# 방송시간: 04:50 방송상품: [TV상품] [GS단독] The NEW 바툼 시스템 에어
# 방송시간: 05:30 방송상품: [TV상품] 개랭이 순천만 김치2종 총4kg 고들빼기김치 1kg 2팩 갓김치 1kg 2팩
# 방송시간: 06:00 방송상품: [TV상품] [상담만 받아도 특별한 혜택] 나에게맞춘플러스간편건강보험(하이클래스암)
# 방송시간: 07:15 방송상품: [TV상품] 스케쳐스 25FW 여성용 우노 키높이 슬립인스 워킹화
# 방송시간: 08:15 방송상품: [TV상품] 쏘울 25FW 소모 캐시100 가디건[런칭 가격159,900원]
# 방송시간: 10:25 방송상품: [TV상품] 베라왕 플랫 판토 선글라스 VW532
# 방송시간: 11:35 방송상품: [TV상품] [현대의료기] 포그니처 LED 템바 황토 흙침대 S+리프트테이블
# 방송시간: 12:35 방송상품: [TV상품] 유아굿 여성 25FW 플라워 패턴 플리츠 셋업 4종
# 방송시간: 13:35 방송상품: [TV상품] LG 오브제 워시콤보 스팀+미니워시 FH25ESX,FH25GSX
# 방송시간: 14:35 방송상품: [TV상품] [더블구성] 휴스톰 이오닉 플라즈마 BLDC 드라이기 거치대 세트
# 방송시간: 15:35 방송상품: [TV상품] 쿡셀 블랙큐브 세라믹에디션 패키지
# 방송시간: 16:35 방송상품: [TV상품] [싱글세트] 경락괄사마사지 리파 카사M1 + 가히 바운싱크림 1개(50ml)
# 방송시간: 17:35 방송상품: [TV상품] 코렐 일렉 에어글라스 에어프라이어 스페셜패키지 (1.5L 글라스 2개 더)
# 방송시간: 18:35 방송상품: [TV상품] 모두투어 북유럽 4국 10일, 3,599,000원~
# 방송시간: 19:35 방송상품: [TV상품] [상담만 받아도 특별한혜택] (무)원스톱프리미엄암보험_진단금플랜
# 방송시간: 20:45 방송상품: [TV상품] [에몬스] 위브릭 3인 듀얼스윙M 기능성 패브릭 소파
# 방송시간: 21:45 방송상품: [TV상품] 제메이스 24K순금 행운 피쉬 더블 반지+방송에서만 가드링 2종+24K순금 5종
# 방송시간: 22:55 방송상품: [TV상품] 모르간 울 니트 가디건 3종
# 방송시간: 23:55 방송상품: [TV상품] 최신상 그레이트헤어 노워시 트리트먼트 시즌2 슬림패키지
