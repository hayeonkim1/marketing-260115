# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import time
import re

URL = "https://www.lottecinema.co.kr/"

service = Service(ChromeDriverManager().install())
options = Options()

# options.add_argument("--headless")
# options.add_argument("--disable-gpu")
options.add_argument("--disable-dev-shm-usage")
options.add_argument("--window-size=1920,1080")
options.add_argument("--start-maximized")
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/145.0.0.0 Safari/537.36")
options.add_argument("--lang=ko_KR")
options.add_argument("--no-sandbox")

driver = webdriver.Chrome(service=service, options=options)
driver.get(URL)
time.sleep(2)

btn = driver.find_elements(By.CSS_SELECTOR, "div#nav > ul > li")
btn[1].click()
time.sleep(2)

btn2 = driver.find_element(By.CSS_SELECTOR, "div > a.btn_txt_more.ty2").click()
time.sleep(2)

# movie_datas = list()
# info_btns = driver.find_elements(By.CSS_SELECTOR, "div > a.btn_col3.ty3")

# for movie_data in range(10) :
info_btn = driver.find_elements(By.CSS_SELECTOR, "div > a.btn_col3.ty3")
info_btn.get_attribute("href").click()
time.sleep(2)
    

driver.quit()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 41
#      36 # movie_datas = list()
#      37 # info_btns = driver.find_elements(By.CSS_SELECTOR, "div > a.btn_col3.ty3")
#      38
#      39 # for movie_data in range(10) :
#      40 info_btn = driver.find_elements(By.CSS_SELECTOR, "div > a.btn_col3.ty3")
# ---> 41 info_btn.get_attribute("href").click()
#      42 time.sleep(2)
#      45 driver.quit()
#
# AttributeError: 'list' object has no attribute 'get_attribute'

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import time
import re

URL = "https://www.lottecinema.co.kr/"

service = Service(ChromeDriverManager().install())
options = Options()

# options.add_argument("--headless")
# options.add_argument("--disable-gpu")
options.add_argument("--disable-dev-shm-usage")
options.add_argument("--window-size=1920,1080")
options.add_argument("--start-maximized")
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/145.0.0.0 Safari/537.36")
options.add_argument("--lang=ko_KR")
options.add_argument("--no-sandbox")

driver = webdriver.Chrome(service=service, options=options)
driver.get(URL)
time.sleep(2)

btn = driver.find_elements(By.CSS_SELECTOR, "div#nav > ul > li")
btn[1].click()
time.sleep(2)

btn2 = driver.find_element(By.CSS_SELECTOR, "div > a.btn_txt_more.ty2").click()
time.sleep(2)



for movie_data in range(10) :
    try:
        info_btn = driver.find_elements(By.CSS_SELECTOR, "ul > li div.inner > a")
        info_btn[2].click()
        time.sleep(2)
    except: 
        continue

driver.quit()

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import time
import re

URL = "https://www.lottecinema.co.kr/"

service = Service(ChromeDriverManager().install())
options = Options()

# options.add_argument("--headless")
# options.add_argument("--disable-gpu")
options.add_argument("--disable-dev-shm-usage")
options.add_argument("--window-size=1920,1080")
options.add_argument("--start-maximized")
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/145.0.0.0 Safari/537.36")
options.add_argument("--lang=ko_KR")
options.add_argument("--no-sandbox")

driver = webdriver.Chrome(service=service, options=options)
driver.get(URL)
time.sleep(2)

btn = driver.find_elements(By.CSS_SELECTOR, "div#nav > ul > li")
btn[1].click()
time.sleep(2)

btn2 = driver.find_element(By.CSS_SELECTOR, "div > a.btn_txt_more.ty2")
btn2.click()
time.sleep(2)



info_btns = driver.find_elements(By.CSS_SELECTOR, "div.inner a")

for info_btn in info_btns : 
    info =info_btn.get_attribute("href")
    driver.get(info)

time.sleep(2)
   
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# Cell In[23], line 42
#      39 info_btns = driver.find_elements(By.CSS_SELECTOR, "div.inner a")
#      41 for info_btn in info_btns :
# ---> 42     info =info_btn.get_attribute("href")
#      43     driver.get(info)
#      45 time.sleep(2)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\selenium\webdriver\remote\webelement.py:213, in WebElement.get_attribute(self, name)
#     211 if getAttribute_js is None:
#     212     _load_js()
# --> 213 attribute_value = self.parent.execute_script(
#     214     f"/* getAttribute */return ({getAttribute_js}).apply(null, arguments);", self, name
#     215 )
#     216 return attribute_value
#
# File ~\AppData\Roaming\Python\Python313\site-packages\selenium\webdriver\remote\webdriver.py:518, in WebDriver.execute_script(self, script, *args)
#     515 converted_args = list(args)
# ...
