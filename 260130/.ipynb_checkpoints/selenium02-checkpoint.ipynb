# %%
from selenium import webdriver 
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager 
import time


service = Service(ChromeDriverManager().install())


options = Options()
# options.add_argument("--headless") 
# options.add_argument("--disable-gpu")
options.add_argument("--disable-dev-shm-usage")
options.add_argument("--window-size=1920,1080")
options.add_argument("--start-maximized") 
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36")
options.add_argument("--lang=ko_KR") 
options.add_argument("--no-snadbox") 


driver = webdriver.Chrome(service=service)
driver.get("https://crawlingtest.netlify.app/")



# 1문서상 course 이라는 클래스값을 가지고 있는 요소만 크롤링해와서 출력

# elements = driver.find_elements(By.CSS_SELECTOR, ".course")
# for element in elements : 
#     print(element.text)


#2 커리큘럼 일정 > 테이블 내용을 크롤링 출력!

elements = driver.find_elements(By.TAG_NAME, "td")
for element in elements : 
    print(element.text)

driver.quit()
# Out:
# 일정
# 커리큘럼 타이틀
# 난이도
# 5.1 ~ 6.15
# 나만의 엣지있는 블로그 사이트 만들기 (취미로 익히는 IT)
# 초급
# 6.16 ~ 7.31
# 파이썬과 데이터과학 첫걸음 (IT 기본기 익히기)
# 중급

# %% [markdown]
# # Mission
# 1)구글 스컬러 사이트 접속
# 2)검색바에 SEO Marketing 키워드 자동입력
# 3) 검색 자동실행
# 4)논문 제목 5개 크롤링 한 후 출력

# %%
셀레니움으로 웹사이트 접속
검색바에 검색어 "SEO Marketing" 자동입력
검색버튼 클릭
논문제목 5개 크롤링

# %%
from selenium import webdriver 
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager 
import time


service = Service(ChromeDriverManager().install())


options = Options()
# options.add_argument("--headless") 
# options.add_argument("--disable-gpu")
options.add_argument("--disable-dev-shm-usage")
options.add_argument("--window-size=1920,1080")
options.add_argument("--start-maximized") 
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36")
options.add_argument("--lang=ko_KR") 
options.add_argument("--no-snadbox") 


driver = webdriver.Chrome(service=service)
driver.get("https://scholar.google.com/")

element = driver.find_element(By.NAME, "q")
element.send_keys("SEO Marketing")
time.sleep(4)
element.send_keys(Keys.RETURN)

time.sleep(15)
# print(element)

articles = driver.find_elements(By.CSS_SELECTOR,"div.gs_ri > h3 > a")
for index, article in enumerate(articles[:5]) : 
    print(index+1, article.text)


driver.quit()
# Out:
# 1 Inbound marketing and SEO: Insights from the Moz Blog
# 2 The role of search engine optimization in search marketing
# 3 Application marketing strategy search engine optimization (SEO)
# 4 Effective SEO and content marketing: the ultimate guide for maximizing free web traffic
# 5 Optimize: How to attract and engage more customers by integrating SEO, social media, and content marketing

# %%
#MISSION 2
# https://brunch.co.kr/ 에서 Recommended Articles 제목 크롤링하기

# %%
from selenium import webdriver 
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager 
import time


service = Service(ChromeDriverManager().install())


options = Options()
# options.add_argument("--headless") 
# options.add_argument("--disable-gpu")
options.add_argument("--disable-dev-shm-usage")
options.add_argument("--window-size=1920,1080")
options.add_argument("--start-maximized") 
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36")
options.add_argument("--lang=ko_KR") 
options.add_argument("--no-snadbox") 


driver = webdriver.Chrome(service=service)
driver.get("https://brunch.co.kr")

driver.execute_script("window.scrollTo(0, document.body.scrollHeight)")

time.sleep(5)
elements = driver.find_elements(By.CSS_SELECTOR, "a.link_slide > strong")


time.sleep(5)
for element in elements : 
    print(element.text)

driver.quit()
# Out:
# 천천히 잘 늙어가는 사람들
# 퇴직 후 생긴 가장 뜨거운 일터
# 새벽 헬스장의 사람들
# TJ Maxx, 보물창고 속 득템이 주는 도파민
