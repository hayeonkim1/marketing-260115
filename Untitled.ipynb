# %%
KGAT_ff9c33a7bdc1dd41c6d64b201a6922b2

# %%
# !kaggle competiotions list

# %%
# !kaggle competitions download -c titanic
# Out:
# 'kaggle'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.

# %%
import pandas as pd
train = pd.read_csw
