# %%
#XPATH: 

#html = Hyper Text Markup Language => 웹사이트를 구축,구현하기 위한 마크업 태그
#body, dis, span, li, ui,...

#XML = Extensable Markup Language => 사전에 정의되어있는 html태그보다 유연하게 사용할 수 있는 마크업 문법

#정규화 되어있는 태그, 아이디, 클래스, 선택자, 속성을 활용한 크롤링 방법을 보다 유연하게 찾아 가져오기 위해 탄생된 크롤링 방법(only in selenium)
#xml, xpath 보다 html,id,class, selector등의 방법으로 크롤링하는 형태가 많아지면서 요즘 사용 X



#selenium > 크롤링
#1) find_element vs find_elements
#2) By.Id, By.CSS_SELECTOR, By.TAG_NAME, get_attribute()
#3) By.XPATH

#XPATH  방식으로 특정 값을 찾아오는 문법
"""
/: 절대경로 -> /html/body/div/div

//: all개념 -> 특정 문서상에서 해당되는 내용을 모두다 선택 -> //h1 :  문서상 h1태그로 시작되는 값은 다 찾아와라
@: 속성

//*[@href]: 현재 문서에서 href 속성을 가지고 있는 모든 태그를 찾아와라
//a][@href="https://google.com"] : 현재 문서 내 https://google.com 해당 주소값을 가지고 있는 href 속성을 가지고 있는 모든 a를 찾아와라
(//a)[3] 현재 문서 내 모든 a태그를 찾아오되 3번째 등장하는 a만 찾아와라(주의! 0이아닌 1부터 순서가 시작된다)
(//table)[last()]: 현재 문서 내 모든 table 태그를 찾아와라, 그런데 마지막번째만 찾아와라
(//a)[position()<3] : 현재 문서 내 모든 a 태그를 찾아와라 그런데 3번 미만인 a 만 찾아와라(1,2번째 a만 찾아와라)
//div[@*] : 문서상에서 div태그를 모두 찾아와라 그러나 
contains(@class, "속성") and contains(@class, "속성") -> 복수의 속성을 가지고 있는 경우에 한함

"""

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC #-> 알림창 같은 unexpected condition 방지를 위해
from selenium.webdriver.support.ui import WebDriverWait
from webdriver_manager.chrome import ChromeDriverManager
import time

# 상수값으로서 자주쓰는 변수 목록을 보기쉽게 위쪽에 정리
URL = "https://crawlingtest.netlify.app/"

service = Service(ChromeDriverManager().install())
options= Options()

# options.add_argument("--headless")
# options.add_argument("--disable-gpu")
options.add_argument("--disable-dev-shm-usage")
options.add_argument("--window-size=1920,1080")
options.add_argument("--start-maximized")
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36")
options.add_argument("--lang=ko_KR")
options.add_argument("--no-snadbox")

driver= webdriver.Chrome(service=service, options=options)
driver.get(URL)

# element = driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/div[1]/h1")  #-> copy XPATH로 가져오기


elements = driver.find_elements(By.XPATH, "//*[@href]")

for element in elements :
    print(element.text)

driver.quit()
# Out:
# (왕초보) - 클래스 소개
# (왕초보) - 블로그 개발 필요한 준비물 준비하기
# (왕초보) - Github pages 설정해서 블로그 첫 페이지 만들어보기
# (왕초보) - 초간단 페이지 만들어보기
# (왕초보) - 이쁘게 테마 적용해보기
# (왕초보) - 마크다운 기초 이해하고, 실제 나만의 블로그 페이지 만들기
# (왕초보) - 다양한 마크다운 기법 익혀보며, 나만의 블로그 페이지 꾸며보기
# (초급) - 강사가 실제 사용하는 자동 프로그램 소개 [2]
# (초급) - 필요한 프로그램 설치 시연 [5]
# (초급) - 데이터를 엑셀 파일로 만들기 [9]
# (초급) -     엑셀 파일 이쁘게! 이쁘게! [8]
# (초급) -     나대신 주기적으로 파이썬 프로그램 실행하기 [7]
# (초급) - 파이썬으로 슬랙(slack) 메신저에 글쓰기 [40]
# (초급) - 웹사이트 변경사항 주기적으로 체크해서, 메신저로 알람주기 [12]
# (초급) - 네이버 API 사용해서, 블로그에 글쓰기 [42]
# (중급) - 자동으로 쿠팡파트너스 API 로 가져온 상품 정보, 네이버 블로그/트위터에 홍보하기 [412]

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC #-> 알림창 같은 unexpected condition 방지를 위해
from selenium.webdriver.support.ui import WebDriverWait
from webdriver_manager.chrome import ChromeDriverManager
import time

# 상수값으로서 자주쓰는 변수 목록을 보기쉽게 위쪽에 정리
URL = "https://crawlingtest.netlify.app/"

service = Service(ChromeDriverManager().install())
options= Options()

# options.add_argument("--headless")
# options.add_argument("--disable-gpu")
options.add_argument("--disable-dev-shm-usage")
options.add_argument("--window-size=1920,1080")
options.add_argument("--start-maximized")
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36")
options.add_argument("--lang=ko_KR")
options.add_argument("--no-snadbox")

driver= webdriver.Chrome(service=service, options=options)
driver.get(URL)

#특정 class값을 가지고 있는 태그를 모두 가져와라
# elements = driver.find_elements(By.XPATH, "(//li[@class='course'])[last()]")
# elements = driver.find_elements(By.XPATH, "(//li)[position()<2]")
# elements = driver.find_elements(By.XPATH, "(//li)[position()=1]")

# elements = driver.find_elements(By.XPATH, "//ul[@id='dev_course_list']//*[@class='course']") # 가운데 스이는 // = all = 후손 선택자
# elements = driver.find_elements(By.XPATH, "//ul[@id='dev_course_list']/*[@class='course']") # // = all = 후손 선택자
elements = driver.find_elements(By.XPATH, "//ul[@id='dev_course_list']/*[contains(@class='course')]") # / 후손 선택자



for element in elements :
    print(element.text)

driver.quit()
# Out:
# ---------------------------------------------------------------------------
# InvalidSelectorException                  Traceback (most recent call last)
# Cell In[24], line 35
#      26 driver.get(URL)
#      28 #특정 class값을 가지고 있는 태그를 모두 가져와라
#      29 # elements = driver.find_elements(By.XPATH, "(//li[@class='course'])[last()]")
#      30 # elements = driver.find_elements(By.XPATH, "(//li)[position()<2]")
#    (...)
#      33 # elements = driver.find_elements(By.XPATH, "//ul[@id='dev_course_list']//*[@class='course']") # 가운데 스이는 // = all = 후손 선택자
#      34 # elements = driver.find_elements(By.XPATH, "//ul[@id='dev_course_list']/*[@class='course']") # // = all = 후손 선택자
# ---> 35 elements = driver.find_elements(By.XPATH, "//ul[@id='dev_course_list']/*[contains(@class='course')]") # // = all = 후손 선택자
#      39 for element in elements :
#      40     print(element.text)
#
# ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC #-> 알림창 같은 unexpected condition 방지를 위해
from selenium.webdriver.support.ui import WebDriverWait
from webdriver_manager.chrome import ChromeDriverManager
import time

# 상수값으로서 자주쓰는 변수 목록을 보기쉽게 위쪽에 정리
URL = "https://davelee-fun.github.io/"

service = Service(ChromeDriverManager().install())
options= Options()

# options.add_argument("--headless")
# options.add_argument("--disable-gpu")
options.add_argument("--disable-dev-shm-usage")
options.add_argument("--window-size=1920,1080")
options.add_argument("--start-maximized")
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36")
options.add_argument("--lang=ko_KR")
options.add_argument("--no-snadbox")

driver= webdriver.Chrome(service=service, options=options)
driver.get(URL)

# element = driver.find_elements(By.XPATH, "//p[@*]")



for element in elements :
    print(element.text)


driver.quit()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 29
#      26 driver.get(URL)
#      28 element = driver.find_elements(By.XPATH, "//p[@*]")
# ---> 29 print(element.text)
#      31 driver.quit()
#
# AttributeError: 'list' object has no attribute 'text'
