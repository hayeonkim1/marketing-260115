# %%
#머신러닝 모델!!
#모델을 커스텀하는 내용에 대해서는 깊이 공부 x
#미분,선형대수,확통,가우스 분포(정규분포), 오일러 상수, 잔차(residual) 등 다양한 수학개념, 공식등


#머신러닝 모델이 어떤 종류로 나눠져 있는지
#각 머신러닝 모델의 장단점(특징)
#각 머신러닝 모델이 어떤 알고리즘, 기법활용 >  간단한 수학공식

# %%
#1. KNN(K-Nearest Neighbor) 기법
#k => 상수값을 의미 => 데이터에 따라서 Units
#굉장히 오래된 머신러닝 모델 중 하나
#K값 (상수)를 설정한 후, K거리 안에 들어온 기존 데이터(학습된)의 타입(분류)이 다수인 쪽으로 새로운 데이터를 예측하는 기법

#장점: 예측이 단순하고 코드의 난이도가 낮음
#단점: 해당 기법의 핵심은 알맞은|적절한 K값 설정 => 엄청 어려움 (데이터 행수 및 feature)
#군집화(Clustering)가 필요한 경우에 많이 사용하는 편 (양자택일 값 결정할때 주로 사용)

# %%
#2. Logistic Regression = 논리회귀 모델
#Regression = 회귀 
#대부분의 데이터 값은 해당 그룹 및 단체의 평균갑승로 돌아가려는 성향이 있다.
#Logistic Regression => 모델이 하는 역할
