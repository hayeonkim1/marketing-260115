# %% [markdown]
# # 파이썬 Class
#
# - 클래스 : 자주 반복적으로 사용하고자하는 기능을 메뉴얼처럼 정의해놓고, 필요에 따라 해당값을 복제해 사용하기 위한 문법체계
# - ex) split -> 반복적으로 사용할 것 같은 함수를 Class로 프로그래밍 자체에서 미리 정의해놓은 것.
#
# #프로그래밍 언어 역사
# - C, 파스칼 등 : 클래스 없음
# >절차지향 언어: PP
# > 냉장고에 코끼리를 넣는법 : 냉장고 문을 연다 -> 코끼리를 냉장고에 넣는다 -> 냉장고 문을 닫는다.
# > 절차상 움직임 -> 직관,명확
# => 코드가 너무 길어지고 무한 반복 필요 => 메뉴얼의 필요성
#
# - JS, TS, Java, C++, C# :각각 클래스 존재
# > 객체지향 언어 : OOP(Object Oriented Programming)
# > 똑같은 행동 속 바뀌는 요소: 객체
# > 냉장고에 코끼리를 넣는법:
# -코끼리 라는 대상의 정보를 메뉴얼(클래스)로 만든다.
# -해당 메뉴얼을 기반으로 코끼리1(객체)를 만든다.
# -냉장고라는 대상의 정보를 메뉴얼로 만든다.
# -해당 메뉴얼을 기반으로 냉장고1 (객체)를 만든다.
# -코끼리1 객체가 가진 기능을 사용해 냉장고1 객체의 문을 열게한다.
# -코끼리1의 객체가 가지고 있는 기능을 사용해서 냉장고1 객체 안에 넣는다.
# -코기리1의 객체가 가지고 있는 기능을 사용해 냉장고1 객체 문을 닫는다.

# %%
#우리가 직접만든 독립적 함수
def print_string(data) :  
    print(data)

# %%
print_string("David")  # 영문자() : -> 함수  #내가 만든 함수
# Out:
# David

# %%
#string: 클래스를 통해서 만들어진 매서드 함수

string = "David Dave"   #split() : 내가 만든 함수 아님
print(string.split())
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'removeprefix', 'removesuffix', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']

# %%
#class 선언
class Student : 
    def __init__ (self, name, grade) :
        self.name = name
        self.grade = grade
#매서드 함수 
    def study(self) :
        print(self.name, "공부합니다.")
    def take_exam(self) :
        print(self.name, subject, "공부합니다.")

# %%
student1= Student("David", 3)
student2= Student("Jane", 2)

print(student1.name, student1.grade)
print(student2.name, student2.grade)
# Out:
# David 3
# Jane 2

# %%
student1.study()
# Out:
# David 공부합니다.

# %%
student1.take_exam("수학")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 student1.take_exam("수학")
#
# TypeError: Student.take_exam() takes 1 positional argument but 2 were given
